# %%
import pandas as pd

# %%
df = pd.read_parquet("data_cleaning_pvm_cube_input_df_sales.parquet")

# %%
df.head()
# Out:
#       customer product_line     2021_1     2021_2     2021_3      2021_4  \
# 0   Customer_1    Product_A    0.00000    0.00000     0.0000    0.000000
# 1   Customer_1    Product_B  389.52225  701.14005  2804.5602  864.739395
# 2   Customer_1    Product_C    0.00000    0.00000     0.0000    0.000000
# 3  Customer_10    Product_A  406.81525  732.26745  2929.0698  903.129855
# 4  Customer_10    Product_B  285.96000  514.72800  2058.9120  634.831200
#
#       2021_5      2021_6       2021_7      2021_8  ...      2022_11  \
# 0    0.00000    0.000000     0.000000    0.000000  ...     0.000000
# 1  701.14005  771.254055  1752.850125  771.254055  ...     0.000000
# 2    0.00000    0.000000     0.000000    0.000000  ...     0.000000
# 3  732.26745  805.494195  1830.668625  805.494195  ...  1126.517990
# 4  514.72800  566.200800  1286.820000  566.200800  ...  2203.840158
#
#        2022_12       2023_1       2023_2       2023_3       2023_4  \
# ...

# %%
sum(df.loc[0] < 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sum(df.loc[0] < 0)
#
# File ~/Documents/py_api/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Documents/py_api/lib/python3.13/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~/Documents/py_api/lib/python3.13/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...
